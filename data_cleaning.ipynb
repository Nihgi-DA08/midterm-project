# %% [markdown]
# # DATA CLEANING
#
# Notebook này làm sạch dữ liệu khoản vay ngân hàng Ấn Độ trước khi phân tích rủi ro.

# %% [markdown]
# ## 1. Khai báo thư viện và đường dẫn
#
# Các file nguồn và file xuất được gom vào folder riêng để repo gọn hơn và notebook có thể chạy lại từ thư mục gốc.

# %%
from pathlib import Path

import pandas as pd

# Tất cả đường dẫn đều tương đối theo root của repo.
SOURCE_PATH = Path("excel/India_bank_loan_risk.xlsx")
DATA_DIR = Path("data")
VALID_OUTPUT = DATA_DIR / "data_valid.csv"
INVALID_OUTPUT = DATA_DIR / "data_invalid.csv"

# Đảm bảo thư mục data tồn tại trước khi ghi kết quả làm sạch.
DATA_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 2. Khai báo tên cột và miền giá trị hợp lệ
#
# Nhóm hằng số này giúp phần kiểm tra dữ liệu dễ đọc hơn, đồng thời tránh lặp lại tên cột ở nhiều cell.

# %%
# Tên cột gốc trong file Excel.
CN_INC = "Income"
CN_AGE = "Age"
CN_EXP = "Experience"
CN_MS = "Married/Single"
CN_HO = "House_Ownership"
CN_CO = "Car_Ownership"
CN_PRO = "Profession"
CN_STA = "STATE"
CN_RF = "Risk_Flag"

# Miền giá trị hợp lệ cho các biến phân loại.
MS_VALID_VALUES = ["married", "single"]
HO_VALID_VALUES = ["rented", "norent noown", "owned"]
CO_VALID_VALUES = ["no", "yes"]
STATE_VALID_VALUES = [
    "Andhra Pradesh",
    "Arunachal Pradesh",
    "Assam",
    "Bihar",
    "Chhattisgarh",
    "Goa",
    "Gujarat",
    "Haryana",
    "Himachal Pradesh",
    "Jharkhand",
    "Karnataka",
    "Kerala",
    "Madhya Pradesh",
    "Maharashtra",
    "Manipur",
    "Meghalaya",
    "Mizoram",
    "Nagaland",
    "Odisha",
    "Punjab",
    "Rajasthan",
    "Sikkim",
    "Tamil Nadu",
    "Telangana",
    "Tripura",
    "Uttar Pradesh",
    "Uttarakhand",
    "West Bengal",
    "Andaman and Nicobar",
    "Chandigarh",
    "Dadra and Nagar Haveli and Daman and Diu",
    "Delhi",
    "Jammu and Kashmir",
    "Lakshadweep",
    "Ladakh",
    "Puducherry",
]
RISK_VALID_VALUES = [0, 1]

# %% [markdown]
# ## 3. Hàm chuẩn hóa dùng chung
#
# Hai hàm dưới đây tập trung phần chuyển kiểu và làm sạch text, để logic kiểm tra chính chỉ còn mô tả điều kiện hợp lệ.

# %%
def normalize_text(series: pd.Series) -> pd.Series:
    # Chuẩn hóa chuỗi: bỏ khoảng trắng thừa, đổi gạch dưới thành khoảng trắng và viết thường.
    return (
        series.astype("string")
        .str.strip()
        .str.replace("_", " ", regex=False)
        .str.split()
        .str.join(" ")
        .str.lower()
    )


def parse_nullable_int(series: pd.Series) -> pd.Series:
    # Ép dữ liệu số sang Int64 nullable để giữ được giá trị thiếu khi kiểm tra hợp lệ.
    return pd.to_numeric(series, errors="coerce").astype("Int64")

# %% [markdown]
# ## 4. Đọc và chuẩn hóa dữ liệu nguồn
#
# Dữ liệu được tách thành DataFrame chuẩn hóa để phân tích và DataFrame gốc để truy vết các dòng không hợp lệ.

# %%
raw_df = pd.read_excel(SOURCE_PATH)

# Chuẩn hóa từng cột trước khi kiểm tra điều kiện hợp lệ.
clean_candidates = pd.DataFrame(
    {
        "Income": parse_nullable_int(raw_df[CN_INC]),
        "Age": parse_nullable_int(raw_df[CN_AGE]),
        "Experience": parse_nullable_int(raw_df[CN_EXP]),
        "Married/Single": normalize_text(raw_df[CN_MS]),
        "House Ownership": normalize_text(raw_df[CN_HO]),
        "Car Ownership": normalize_text(raw_df[CN_CO]),
        "Profession": normalize_text(raw_df[CN_PRO]).str.capitalize(),
        "State": normalize_text(raw_df[CN_STA]).str.title().str.replace(" And ", " and ", regex=False),
        "Risk Flag": parse_nullable_int(raw_df[CN_RF]),
    }
)

clean_candidates.head()
# Out:
#     Income  Age  Experience Married/Single House Ownership Car Ownership  \
# 0  1303834   23           3         single          rented            no
# 1  7574516   40          10         single          rented            no
# 2  3991815   66           4        married          rented            no
# 3  6256451   41           2         single          rented           yes
# 4  5768871   47          11         single          rented            no
#
#             Profession           State  Risk Flag
# 0  Mechanical engineer  Madhya Pradesh          0
# 1   Software developer     Maharashtra          0
# 2     Technical writer          Kerala          0
# 3   Software developer          Odisha          1
# 4        Civil servant      Tamil Nadu          1

# %% [markdown]
# ## 5. Lọc dòng hợp lệ và xuất CSV
#
# Một dòng được giữ lại khi đủ dữ liệu, các biến số hợp lý và các biến phân loại nằm trong miền cho phép.

# %%
# Điều kiện số học giúp loại các dòng âm tuổi/thu nhập/kinh nghiệm hoặc tuổi không khớp kinh nghiệm.
valid_mask = (
    clean_candidates.notna().all(axis=1)
    & clean_candidates["Income"].ge(0)
    & clean_candidates["Age"].ge(18)
    & clean_candidates["Experience"].ge(0)
    & (clean_candidates["Age"] - clean_candidates["Experience"]).ge(18)
    & clean_candidates["Married/Single"].isin(MS_VALID_VALUES)
    & clean_candidates["House Ownership"].isin(HO_VALID_VALUES)
    & clean_candidates["Car Ownership"].isin(CO_VALID_VALUES)
    & clean_candidates["State"].isin(STATE_VALID_VALUES)
    & clean_candidates["Risk Flag"].isin(RISK_VALID_VALUES)
).fillna(False)

valid_df = clean_candidates.loc[valid_mask].reset_index(drop=True)
invalid_df = raw_df.loc[~valid_mask].drop(columns=["Unnamed: 0"], errors="ignore").reset_index(drop=True)

# Xuất index=False và bỏ cột index tự sinh để CSV không mang thêm dữ liệu autogen.
valid_df.to_csv(VALID_OUTPUT, index=False)
invalid_df.to_csv(INVALID_OUTPUT, index=False)

print(f"Tổng số dòng nguồn: {len(raw_df):,}")
print(f"Số dòng hợp lệ: {len(valid_df):,} -> {VALID_OUTPUT}")
print(f"Số dòng không hợp lệ: {len(invalid_df):,} -> {INVALID_OUTPUT}")
# Out:
# Tổng số dòng nguồn: 43,190
# Số dòng hợp lệ: 37,657 -> data\data_valid.csv
# Số dòng không hợp lệ: 5,533 -> data\data_invalid.csv

# %% [markdown]
# ## Tóm tắt làm sạch dữ liệu
#
# - Dữ liệu gốc được đọc từ `excel/India_bank_loan_risk.xlsx`.
# - Các cột số được ép kiểu an toàn bằng `to_numeric(..., errors="coerce")` để phát hiện giá trị lỗi.
# - Text được chuẩn hóa về chữ thường, bỏ khoảng trắng thừa và thống nhất cách ghi state/profession.
# - File hợp lệ được ghi vào `data/data_valid.csv`, file không hợp lệ được ghi vào `data/data_invalid.csv`.
